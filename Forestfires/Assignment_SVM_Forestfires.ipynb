# %% [markdown]
# Assignment: SVM_Forestfires_classification

# %%
# importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing CSV file
Forestfire= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ExcelR (1)/Assignments/SVM/forestfires.csv')

# %%
# Copy the data into other object
df= Forestfire.copy()

# %%
# General insights into data:

# 1. shape of data
df.shape
# Out:
# (517, 31)

# %%
# 2. how does data look?
df.sample(5)   # sample shows the random 5 rows from the data
# Out:
#     month  day  FFMC    DMC  ...  monthnov  monthoct  monthsep  size_category
# 320   sep  thu  92.8  119.0  ...         0         0         1          large
# 124   sep  fri  94.3   85.1  ...         0         0         1          small
# 390   feb  mon  84.7    9.5  ...         0         0         0          large
# 5     aug  sun  92.3   85.3  ...         0         0         0          small
# 304   may  sat  85.1   28.0  ...         0         0         0          small
#
# [5 rows x 31 columns]

# %%
# 3. Check for datatypes of variables:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   month          517 non-null    object
#  1   day            517 non-null    object
#  2   FFMC           517 non-null    float64
#  3   DMC            517 non-null    float64
#  4   DC             517 non-null    float64
#  5   ISI            517 non-null    float64
#  6   temp           517 non-null    float64
#  7   RH             517 non-null    int64
#  8   wind           517 non-null    float64
#  9   rain           517 non-null    float64
#  10  area           517 non-null    float64
#  11  dayfri         517 non-null    int64
#  12  daymon         517 non-null    int64
#  13  daysat         517 non-null    int64
#  14  daysun         517 non-null    int64
#  15  daythu         517 non-null    int64
#  16  daytue         517 non-null    int64
# ...

# %% [markdown]
# It is clear from info that there are no null values
# also, size_category needs to converted into the category datatype

# %%
# 4. Check for null values

df.isnull().sum()
# Out:
# month            0
# day              0
# FFMC             0
# DMC              0
# DC               0
# ISI              0
# temp             0
# RH               0
# wind             0
# rain             0
# area             0
# dayfri           0
# daymon           0
# daysat           0
# daysun           0
# daythu           0
# daytue           0
# daywed           0
# monthapr         0
# monthaug         0
# monthdec         0
# monthfeb         0
# monthjan         0
# monthjul         0
# monthjun         0
# monthmar         0
# monthmay         0
# monthnov         0
# monthoct         0
# monthsep         0
# size_category    0
# dtype: int64

# %%
# 5. How data looks numerically:
df.describe()
# Out:
#              FFMC         DMC          DC  ...    monthnov    monthoct    monthsep
# count  517.000000  517.000000  517.000000  ...  517.000000  517.000000  517.000000
# mean    90.644681  110.872340  547.940039  ...    0.001934    0.029014    0.332689
# std      5.520111   64.046482  248.066192  ...    0.043980    0.168007    0.471632
# min     18.700000    1.100000    7.900000  ...    0.000000    0.000000    0.000000
# 25%     90.200000   68.600000  437.700000  ...    0.000000    0.000000    0.000000
# 50%     91.600000  108.300000  664.200000  ...    0.000000    0.000000    0.000000
# 75%     92.900000  142.400000  713.900000  ...    0.000000    0.000000    1.000000
# max     96.200000  291.300000  860.600000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# It can be seen that the numerical variables are having the different scaling, which can be effect the model. hence, the necessary treatment needs to be applied

# %%
# 6. Check foe duplicate rows:
df.duplicated().sum()
# Out:
# 8

# %% [markdown]
# we need to remove the duplicate rows

# %%
df= df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind',
#        'rain', 'area', 'dayfri', 'daymon', 'daysat', 'daysun', 'daythu',
#        'daytue', 'daywed', 'monthapr', 'monthaug', 'monthdec', 'monthfeb',
#        'monthjan', 'monthjul', 'monthjun', 'monthmar', 'monthmay', 'monthnov',
#        'monthoct', 'monthsep', 'size_category'],
#       dtype='object')

# %%
df_numerical_data= df[['FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind',
       'rain', 'area']]

# %%
# 7. Correlation
df_numerical_data.corr()
# Out:
#           FFMC       DMC        DC  ...      wind      rain      area
# FFMC  1.000000  0.382925  0.331956  ... -0.030409  0.052280  0.040998
# DMC   0.382925  1.000000  0.681446  ... -0.104563  0.071017  0.076932
# DC    0.331956  0.681446  1.000000  ... -0.202856  0.033772  0.051542
# ISI   0.531926  0.309459  0.229757  ...  0.104834  0.062132  0.008429
# temp  0.431744  0.470875  0.496608  ... -0.227754  0.067911  0.099173
# RH   -0.306262  0.062772 -0.047971  ...  0.070721  0.094343 -0.074554
# wind -0.030409 -0.104563 -0.202856  ...  1.000000  0.059332  0.012623
# rain  0.052280  0.071017  0.033772  ...  0.059332  1.000000 -0.006511
# area  0.040998  0.076932  0.051542  ...  0.012623 -0.006511  1.000000
#
# [9 rows x 9 columns]

# %%
df2= pd.get_dummies(df['size_category'], drop_first=True)

# %%
df1= pd.concat([df, df2], axis=1)
df1.head()
# Out:
#   month  day  FFMC   DMC  ...  monthoct  monthsep  size_category  small
# 0   mar  fri  86.2  26.2  ...         0         0          small      1
# 1   oct  tue  90.6  35.4  ...         1         0          small      1
# 2   oct  sat  90.6  43.7  ...         1         0          small      1
# 3   mar  fri  91.7  33.3  ...         0         0          small      1
# 4   mar  sun  89.3  51.3  ...         0         0          small      1
#
# [5 rows x 32 columns]

# %%
sns.heatmap(df_numerical_data.corr())

# %%
# Exploratory Data Analysis

# Univariate Analysis
sns.countplot(df['month'], hue= df['size_category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['day'], hue=df['size_category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['size_category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(df['FFMC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['DMC'])

# %%
sns.distplot(df['DC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['ISI'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['area'])

# %%
sns.distplot(df['rain'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['RH'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['temp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['wind'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Bivariate analysis
df_numerical_data= pd.concat([df_numerical_data, df2], axis=1)
sns.pairplot(df_numerical_data, hue='small')

# %%
sns.boxplot(df1['small'], df1['wind'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['RH'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['FFMC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['DMC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['DC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['ISI'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['temp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['area'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df1['small'], df1['rain'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df1.head()
# Out:
#   month  day  FFMC   DMC  ...  monthoct  monthsep  size_category  small
# 0   mar  fri  86.2  26.2  ...         0         0          small      1
# 1   oct  tue  90.6  35.4  ...         1         0          small      1
# 2   oct  sat  90.6  43.7  ...         1         0          small      1
# 3   mar  fri  91.7  33.3  ...         0         0          small      1
# 4   mar  sun  89.3  51.3  ...         0         0          small      1
#
# [5 rows x 32 columns]

# %%
# Distributing features into dependant and independant features
X=df1.drop(['month', 'day', 'size_category', 'small'], axis=1)
y= df1['small']

# %%
# Feature engineering
# data needs to standerdised for SVM  model
from sklearn.preprocessing  import MinMaxScaler
from sklearn.model_selection import train_test_split

# first splitting data into train and test 
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# standerdisation of data
scaler= MinMaxScaler()
scaler.fit(X_train)
X_train_scaled= scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
# Converting numpy arrayes to Dataframe
X_train_scaled= pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled= pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_scaled.shape, X_test_scaled.shape, y_train.shape, y_test.shape
# Out:
# ((407, 28), (102, 28), (407,), (102,))

# %%
# model Building 
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import  accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score

# %%
# GridDearch CV
# Using RBF Kernal 
clf= SVC()
param_grid= {'kernel': ['rbf', 'poly', 'linear'], 'gamma': [50, 10, 6, 5, 4, 0.5], 'degree': [2,3,4], 'C': [15,14,13,12,11,10,1,0.1,0.01,0.001]}
gsv= GridSearchCV(clf, param_grid=param_grid, cv=10)
gsv.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [15, 14, 13, 12, 11, 10, 1, 0.1, 0.01, 0.001],
#                          'degree': [2, 3, 4], 'gamma': [50, 10, 6, 5, 4, 0.5],
#                          'kernel': ['rbf', 'poly', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
#printing the best scores of GSV
gsv.best_params_, gsv.best_score_
# Out:
# ({'C': 10, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}, 0.8698780487804878)

# %%
# modeling with best parameters
clf= SVC(kernel='poly', C= 10, degree=2, gamma=10)
clf.fit(X_train_scaled, y_train)

y_pred= clf.predict(X_test_scaled)
acc= accuracy_score(y_test, y_pred)
print('Accuracy :', acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy : 0.8823529411764706
# array([[19,  8],
#        [ 4, 71]])

# %%
# pickle the model
import pickle
filename= 'Final_model'
pickle.dump(clf, open(filename, 'wb'))
